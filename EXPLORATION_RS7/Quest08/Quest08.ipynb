# %% [markdown]
# # Quest08: Segmentation map으로 도로 이미지 만들기
#
# ### 평가문항에 맞춰서 작성
# **1. pix2pix 모델 학습을 위해 필요한 데이터셋을 적절히 구축하였다.**
# -> 데이터 분석 과정 및 한 가지 이상의 augmentation을 포함한 데이터셋 구축 과정이 체계적으로 제시되었다.
#
# **2. pix2pix 모델을 구현하여 성공적으로 학습 과정을 진행하였다.**
# -> U-Net generator, discriminator 모델 구현이 완료되어 train_step의 output을 확인하고 개선하였다.
#
# **3. 학습 과정 및 테스트에 대한 시각화 결과를 제출하였다.**
# -> 10 epoch 이상의 학습을 진행한 후 최종 테스트 결과에서 진행한 epoch 수에 걸맞은 정도의 품질을 확인하였다.

# %%
import os

data_path = os.getenv('HOME')+'/aiffel/conditional_generation/data/cityscapes/train/'
print("number of train examples :", len(os.listdir(data_path)))
# Out:
# number of train examples : 1000

# %% [markdown]
# # 데이터 로드

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

plt.figure(figsize=(20,15))
for i in range(1, 7):
    f = data_path + os.listdir(data_path)[np.random.randint(800)]
    img = cv2.imread(f, cv2.IMREAD_COLOR)
    plt.subplot(3,2,i)
    plt.imshow(img)

# %% [markdown]
# # 데이터 확인 및 전처리

# %%
f = data_path + os.listdir(data_path)[0]
img = cv2.imread(f, cv2.IMREAD_COLOR)
print(img.shape)
# Out:
# (256, 512, 3)

# %%
import tensorflow as tf

def normalize(x):
    x = tf.cast(x, tf.float32)
    return (x/127.5) - 1

def denormalize(x):
    x = (x+1)*127.5
    x = x.numpy()
    return x.astype(np.uint8)

def load_img(img_path):
    img = tf.io.read_file(img_path)
    img = tf.image.decode_image(img, 3)
    
    w = tf.shape(img)[1] // 2
    sketch = img[:, :w, :] 
    sketch = tf.cast(sketch, tf.float32)
    colored = img[:, w:, :] 
    colored = tf.cast(colored, tf.float32)
    return normalize(sketch), normalize(colored)

f = data_path + os.listdir(data_path)[1]
sketch, colored = load_img(f)

plt.figure(figsize=(10,7))
plt.subplot(1,2,1); plt.imshow(denormalize(sketch))
plt.subplot(1,2,2); plt.imshow(denormalize(colored))

# %%
from tensorflow import image
from tensorflow.keras.preprocessing.image import random_rotation

@tf.function() # 빠른 텐서플로 연산을 위해 @tf.function()을 사용합니다. 
def apply_augmentation(sketch, colored):
    stacked = tf.concat([sketch, colored], axis=-1)
    
    _pad = tf.constant([[30,30],[30,30],[0,0]])
    if tf.random.uniform(()) < .5:
        padded = tf.pad(stacked, _pad, "REFLECT")
    else:
        padded = tf.pad(stacked, _pad, "CONSTANT", constant_values=1.)

    out = image.random_crop(padded, size=[256, 256, 6])
    
    out = image.random_flip_left_right(out)
    out = image.random_flip_up_down(out)
    
    if tf.random.uniform(()) < .5:
        degree = tf.random.uniform([], minval=1, maxval=4, dtype=tf.int32)
        out = image.rot90(out, k=degree)
    
    return out[...,:3], out[...,3:]   

print("✅")
# Out:
# ✅

# %% [markdown]
# # 여러가지 augmentation 방법 적용

# %%
plt.figure(figsize=(15,13))
img_n = 1
for i in range(1, 13, 2):
    augmented_sketch, augmented_colored = apply_augmentation(sketch, colored)
    
    plt.subplot(3,4,i)
    plt.imshow(denormalize(augmented_sketch)); plt.title(f"Image {img_n}")
    plt.subplot(3,4,i+1); 
    plt.imshow(denormalize(augmented_colored)); plt.title(f"Image {img_n}")
    img_n += 1

# %%
from tensorflow import data

def get_train(img_path):
    sketch, colored = load_img(img_path)
    sketch, colored = apply_augmentation(sketch, colored)
    return sketch, colored

train_images = data.Dataset.list_files(data_path + "*.jpg")
train_images = train_images.map(get_train).shuffle(100).batch(4)

sample = train_images.take(1)
sample = list(sample.as_numpy_iterator())
sketch, colored = (sample[0][0]+1)*127.5, (sample[0][1]+1)*127.5

plt.figure(figsize=(10,5))
plt.subplot(1,2,1); plt.imshow(sketch[0].astype(np.uint8))
plt.subplot(1,2,2); plt.imshow(colored[0].astype(np.uint8))

# %%
from tensorflow.keras import layers, Input, Model

class EncodeBlock(layers.Layer):
    def __init__(self, n_filters, use_bn=True):
        super(EncodeBlock, self).__init__()
        self.use_bn = use_bn       
        self.conv = layers.Conv2D(n_filters, 4, 2, "same", use_bias=False)
        self.batchnorm = layers.BatchNormalization()
        self.lrelu= layers.LeakyReLU(0.2)

    def call(self, x):
        x = self.conv(x)
        if self.use_bn:
            x = self.batchnorm(x)
        return self.lrelu(x)

print("✅")
# Out:
# ✅

# %%
class Encoder(layers.Layer):
    def __init__(self):
        super(Encoder, self).__init__()
        filters = [64,128,256,512,512,512,512,512]
        

        # for문과 리스트 filter를 활용해서 EncoderBlock을 쌓아주세요.
        # 조건 1. 첫번째 EncoderBlock의 경우 Batch Normalization을 생략해주세요.


        self.blocks = [] 
        for i, filters in enumerate(filters):
            # 첫 번째 블록은 Batch Normalization 생략
            use_bn = i != 0
            self.blocks.append(EncodeBlock(filters, use_bn))
    
    def call(self, x):
        for block in self.blocks:
            x = block(x)
        return x
    
    def get_summary(self, input_shape=(256,256,3)):
        inputs = Input(input_shape)
        return Model(inputs, self.call(inputs)).summary()

print("✅")
# Out:
# ✅

# %%
Encoder().get_summary()
# Out:
# Model: "model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 256, 256, 3)]     0
# _________________________________________________________________
# encode_block (EncodeBlock)   (None, 128, 128, 64)      3072
# _________________________________________________________________
# encode_block_1 (EncodeBlock) (None, 64, 64, 128)       131584
# _________________________________________________________________
# encode_block_2 (EncodeBlock) (None, 32, 32, 256)       525312
# _________________________________________________________________
# encode_block_3 (EncodeBlock) (None, 16, 16, 512)       2099200
# _________________________________________________________________
# encode_block_4 (EncodeBlock) (None, 8, 8, 512)         4196352
# _________________________________________________________________
# encode_block_5 (EncodeBlock) (None, 4, 4, 512)         4196352
# _________________________________________________________________
# encode_block_6 (EncodeBlock) (None, 2, 2, 512)         4196352
# _________________________________________________________________
# encode_block_7 (EncodeBlock) (None, 1, 1, 512)         4196352
# =================================================================
# Total params: 19,544,576
# Trainable params: 19,538,688
# Non-trainable params: 5,888
# _________________________________________________________________

# %%
class DecodeBlock(layers.Layer):
    def __init__(self, f, dropout=True):
        super(DecodeBlock, self).__init__()
        self.dropout = dropout
        self.Transconv = layers.Conv2DTranspose(f, 4, 2, "same", use_bias=False)
        self.batchnorm = layers.BatchNormalization()
        self.relu = layers.ReLU()
        
    def call(self, x):
        x = self.Transconv(x)
        x = self.batchnorm(x)
        if self.dropout:
            x = layers.Dropout(.5)(x)
        return self.relu(x)

    
class Decoder(layers.Layer):
    def __init__(self):
        super(Decoder, self).__init__()
        filters = [512,512,512,512,256,128,64]


 
        # for문을 이용해서 모델을 쌓아주세요.
        # 조건 1. 3번째 block까지는 Dropout을 사용하되 그 이후에는 Dropout을 사용하지 마세요.
        # for문이 끝난 다음 Conv2DTranspose를 쌓아주되 output 차원수는 3, filter 사이즈는 4, stride는 2로 구성해주시고 자동 패딩 적용해주시되 bias는 사용하지 않습니다.
        # DecoderBlock을 쌓기
        self.blocks = []
        for i, filters in enumerate(filters):
            # 3번째 블록까지는 Dropout 사용
            dropout = i < 3
            self.blocks.append(DecodeBlock(filters, dropout))

        # Conv2DTranspose 쌓기
        self.transconv = layers.Conv2DTranspose(3, 4, 2, "same", use_bias=False)


    def call(self, x):
        for block in self.blocks:
            x = block(x)
        return x
            
    def get_summary(self, input_shape=(1,1,512)):
        inputs = Input(input_shape)
        return Model(inputs, self.call(inputs)).summary()
        
print("✅")
# Out:
# ✅

# %%
Decoder().get_summary()
# Out:
# Model: "model_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_2 (InputLayer)         [(None, 1, 1, 512)]       0
# _________________________________________________________________
# decode_block (DecodeBlock)   (None, 2, 2, 512)         4196352
# _________________________________________________________________
# decode_block_1 (DecodeBlock) (None, 4, 4, 512)         4196352
# _________________________________________________________________
# decode_block_2 (DecodeBlock) (None, 8, 8, 512)         4196352
# _________________________________________________________________
# decode_block_3 (DecodeBlock) (None, 16, 16, 512)       4196352
# _________________________________________________________________
# decode_block_4 (DecodeBlock) (None, 32, 32, 256)       2098176
# _________________________________________________________________
# decode_block_5 (DecodeBlock) (None, 64, 64, 128)       524800
# _________________________________________________________________
# decode_block_6 (DecodeBlock) (None, 128, 128, 64)      131328
# =================================================================
# Total params: 19,539,712
# Trainable params: 19,534,720
# Non-trainable params: 4,992
# _________________________________________________________________

# %%
class EncoderDecoderGenerator(Model):
    def __init__(self):
        super(EncoderDecoderGenerator, self).__init__()
        self.encoder = Encoder()
        self.decoder = Decoder()
    
    def call(self, x):
        x = self.encoder(x)
        x = self.decoder(x)
        return x
   
    def get_summary(self, input_shape=(256,256,3)):
        inputs = Input(input_shape)
        return Model(inputs, self.call(inputs)).summary()
        

EncoderDecoderGenerator().get_summary()
# Out:
# Model: "model_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_3 (InputLayer)         [(None, 256, 256, 3)]     0
# _________________________________________________________________
# encoder_1 (Encoder)          (None, 1, 1, 512)         19544576
# _________________________________________________________________
# decoder_1 (Decoder)          (None, 128, 128, 64)      19539712
# =================================================================
# Total params: 39,084,288
# Trainable params: 39,073,408
# Non-trainable params: 10,880
# _________________________________________________________________

# %%
class EncodeBlock(layers.Layer):
    def __init__(self, n_filters, use_bn=True):
        super(EncodeBlock, self).__init__()
        self.use_bn = use_bn       
        self.conv = layers.Conv2D(n_filters, 4, 2, "same", use_bias=False)
        self.batchnorm = layers.BatchNormalization()
        self.lrelu = layers.LeakyReLU(0.2)

    def call(self, x):
        x = self.conv(x)
        if self.use_bn:
            x = self.batchnorm(x)
        return self.lrelu(x)

    
class DecodeBlock(layers.Layer):
    def __init__(self, f, dropout=True):
        super(DecodeBlock, self).__init__()
        self.dropout = dropout
        self.Transconv = layers.Conv2DTranspose(f, 4, 2, "same", use_bias=False)
        self.batchnorm = layers.BatchNormalization()
        self.relu = layers.ReLU()
        
    def call(self, x):
        x = self.Transconv(x)
        x = self.batchnorm(x)
        if self.dropout:
            x = layers.Dropout(.5)(x)
        return self.relu(x)
    
print("✅")
# Out:
# ✅

# %% [markdown]
# # U-Net Generator 사용

# %%
class UNetGenerator(Model):
    def __init__(self):
        super(UNetGenerator, self).__init__()
        encode_filters = [64,128,256,512,512,512,512,512]
        decode_filters = [512,512,512,512,256,128,64]
        
        self.encode_blocks = []
        for i, f in enumerate(encode_filters):
            if i == 0:
                self.encode_blocks.append(EncodeBlock(f, use_bn=False))
            else:
                self.encode_blocks.append(EncodeBlock(f))
        
        self.decode_blocks = []
        for i, f in enumerate(decode_filters):
            if i < 3:
                self.decode_blocks.append(DecodeBlock(f))
            else:
                self.decode_blocks.append(DecodeBlock(f, dropout=False))
        
        self.last_conv = layers.Conv2DTranspose(3, 4, 2, "same", use_bias=False)
    
    def call(self, x):
        features = []
        for block in self.encode_blocks:
            x = block(x)
            features.append(x)
        
        features = features[:-1]
                    
        for block, feat in zip(self.decode_blocks, features[::-1]):
            x = block(x)
            x = layers.Concatenate()([x, feat])
        
        x = self.last_conv(x)
        return x
                
    def get_summary(self, input_shape=(256,256,3)):
        inputs = Input(input_shape)
        return Model(inputs, self.call(inputs)).summary()

print("✅")
# Out:
# ✅

# %%
UNetGenerator().get_summary()
# Out:
# Model: "model_3"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_4 (InputLayer)            [(None, 256, 256, 3) 0
# __________________________________________________________________________________________________
# encode_block_16 (EncodeBlock)   (None, 128, 128, 64) 3072        input_4[0][0]
# __________________________________________________________________________________________________
# encode_block_17 (EncodeBlock)   (None, 64, 64, 128)  131584      encode_block_16[0][0]
# __________________________________________________________________________________________________
# encode_block_18 (EncodeBlock)   (None, 32, 32, 256)  525312      encode_block_17[0][0]
# __________________________________________________________________________________________________
# encode_block_19 (EncodeBlock)   (None, 16, 16, 512)  2099200     encode_block_18[0][0]
# __________________________________________________________________________________________________
# encode_block_20 (EncodeBlock)   (None, 8, 8, 512)    4196352     encode_block_19[0][0]
# __________________________________________________________________________________________________
# encode_block_21 (EncodeBlock)   (None, 4, 4, 512)    4196352     encode_block_20[0][0]
# __________________________________________________________________________________________________
# encode_block_22 (EncodeBlock)   (None, 2, 2, 512)    4196352     encode_block_21[0][0]
# __________________________________________________________________________________________________
# encode_block_23 (EncodeBlock)   (None, 1, 1, 512)    4196352     encode_block_22[0][0]
# __________________________________________________________________________________________________
# decode_block_14 (DecodeBlock)   (None, 2, 2, 512)    4196352     encode_block_23[0][0]
# __________________________________________________________________________________________________
# concatenate (Concatenate)       (None, 2, 2, 1024)   0           decode_block_14[0][0]
#                                                                  encode_block_22[0][0]
# __________________________________________________________________________________________________
# decode_block_15 (DecodeBlock)   (None, 4, 4, 512)    8390656     concatenate[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 4, 4, 1024)   0           decode_block_15[0][0]
#                                                                  encode_block_21[0][0]
# __________________________________________________________________________________________________
# decode_block_16 (DecodeBlock)   (None, 8, 8, 512)    8390656     concatenate_1[0][0]
# __________________________________________________________________________________________________
# concatenate_2 (Concatenate)     (None, 8, 8, 1024)   0           decode_block_16[0][0]
#                                                                  encode_block_20[0][0]
# __________________________________________________________________________________________________
# decode_block_17 (DecodeBlock)   (None, 16, 16, 512)  8390656     concatenate_2[0][0]
# __________________________________________________________________________________________________
# concatenate_3 (Concatenate)     (None, 16, 16, 1024) 0           decode_block_17[0][0]
#                                                                  encode_block_19[0][0]
# __________________________________________________________________________________________________
# decode_block_18 (DecodeBlock)   (None, 32, 32, 256)  4195328     concatenate_3[0][0]
# __________________________________________________________________________________________________
# concatenate_4 (Concatenate)     (None, 32, 32, 512)  0           decode_block_18[0][0]
#                                                                  encode_block_18[0][0]
# __________________________________________________________________________________________________
# decode_block_19 (DecodeBlock)   (None, 64, 64, 128)  1049088     concatenate_4[0][0]
# __________________________________________________________________________________________________
# concatenate_5 (Concatenate)     (None, 64, 64, 256)  0           decode_block_19[0][0]
#                                                                  encode_block_17[0][0]
# __________________________________________________________________________________________________
# decode_block_20 (DecodeBlock)   (None, 128, 128, 64) 262400      concatenate_5[0][0]
# __________________________________________________________________________________________________
# concatenate_6 (Concatenate)     (None, 128, 128, 128 0           decode_block_20[0][0]
#                                                                  encode_block_16[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_23 (Conv2DTran (None, 256, 256, 3)  6144        concatenate_6[0][0]
# ==================================================================================================
# Total params: 54,425,856
# Trainable params: 54,414,976
# Non-trainable params: 10,880
# __________________________________________________________________________________________________

# %% [markdown]
# # Discriminator 구현

# %%
class DiscBlock(layers.Layer):
    def __init__(self, n_filters, stride=2, custom_pad=False, use_bn=True, act=True):
        super(DiscBlock, self).__init__()
        self.custom_pad = custom_pad
        self.use_bn = use_bn
        self.act = act
        
        if custom_pad:
            self.padding = layers.ZeroPadding2D()
            self.conv = layers.Conv2D(n_filters, 4, stride, "valid", use_bias=False)
        else:
            self.conv = layers.Conv2D(n_filters, 4, stride, "same", use_bias=False)
        
        self.batchnorm = layers.BatchNormalization() if use_bn else None
        self.lrelu = layers.LeakyReLU(0.2) if act else None
        
    def call(self, x):
        if self.custom_pad:
            x = self.padding(x)
            x = self.conv(x)
        else:
            x = self.conv(x)
                
        if self.use_bn:
            x = self.batchnorm(x)
            
        if self.act:
            x = self.lrelu(x)
        return x

# %%
inputs = Input((128,128,32))
out = layers.ZeroPadding2D()(inputs)
out = layers.Conv2D(64, 4, 1, "valid", use_bias=False)(out)
out = layers.BatchNormalization()(out)
out = layers.LeakyReLU(0.2)(out)

Model(inputs, out).summary()
# Out:
# Model: "model_4"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_5 (InputLayer)         [(None, 128, 128, 32)]    0
# _________________________________________________________________
# zero_padding2d (ZeroPadding2 (None, 130, 130, 32)      0
# _________________________________________________________________
# conv2d_24 (Conv2D)           (None, 127, 127, 64)      32768
# _________________________________________________________________
# batch_normalization_45 (Batc (None, 127, 127, 64)      256
# _________________________________________________________________
# leaky_re_lu_24 (LeakyReLU)   (None, 127, 127, 64)      0
# =================================================================
# Total params: 33,024
# Trainable params: 32,896
# Non-trainable params: 128
# _________________________________________________________________

# %%
class Discriminator(Model):
    def __init__(self):
        super(Discriminator, self).__init__()
        
        filters = [64,128,256,512,1]
        self.blocks = [layers.Concatenate()]
        # For문을 활용해서 DiscBlock을 쌓아주세요.
        # 조건 1 : 3번째까지 stride는 2로 주되 이후에는 1로 주세요
        # 조건 2 : 3번째까지 custom padding을 주지 않아도 되는데 이후에는 주세요.
        # 조건 3: 1번째와 5번째에서는 Batch Normalization을 사용하지 마세요.
        # 조건 4 : 1번째부터 4번째까지 LeakyReLU를 적용하고 마지막에는 sigmoid를 적용하세요. (sigmoid의 경우 따로 정의해야 합니다)
        for i, f in enumerate(filters):
            self.blocks.append(DiscBlock(
            n_filters=f,
            stride=2 if i < 3 else 1,
            custom_pad= i >= 3,
            use_bn= (i == 1 or i == 4),
            act= i < 4
            ))
        self.sigmoid = layers.Activation(tf.keras.activations.sigmoid)    
    def call(self, x, y):
        out = self.blocks[0]([x, y])
        for block in self.blocks[1:]:
            out = block(out)
        return self.sigmoid(out)
    
    def get_summary(self, x_shape=(256,256,3), y_shape=(256,256,3)):
        x, y = Input(x_shape), Input(y_shape) 
        return Model((x, y), self.call(x, y)).summary()

# %%
Discriminator().get_summary()
# Out:
# Model: "model_5"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_6 (InputLayer)            [(None, 256, 256, 3) 0
# __________________________________________________________________________________________________
# input_7 (InputLayer)            [(None, 256, 256, 3) 0
# __________________________________________________________________________________________________
# concatenate_7 (Concatenate)     (None, 256, 256, 6)  0           input_6[0][0]
#                                                                  input_7[0][0]
# __________________________________________________________________________________________________
# disc_block (DiscBlock)          (None, 128, 128, 64) 6144        concatenate_7[0][0]
# __________________________________________________________________________________________________
# disc_block_1 (DiscBlock)        (None, 64, 64, 128)  131584      disc_block[0][0]
# __________________________________________________________________________________________________
# disc_block_2 (DiscBlock)        (None, 32, 32, 256)  524288      disc_block_1[0][0]
# __________________________________________________________________________________________________
# disc_block_3 (DiscBlock)        (None, 31, 31, 512)  2097152     disc_block_2[0][0]
# __________________________________________________________________________________________________
# disc_block_4 (DiscBlock)        (None, 30, 30, 1)    8196        disc_block_3[0][0]
# __________________________________________________________________________________________________
# activation (Activation)         (None, 30, 30, 1)    0           disc_block_4[0][0]
# ==================================================================================================
# Total params: 2,767,364
# Trainable params: 2,767,106
# Non-trainable params: 258
# __________________________________________________________________________________________________

# %%
x = tf.random.normal([1,256,256,3])
y = tf.random.uniform([1,256,256,3])

disc_out = Discriminator()(x, y)
plt.imshow(disc_out[0, ... ,0])
plt.colorbar()

# %% [markdown]
# # 학습된 Generator테스트

# %%
from tensorflow.keras import losses

bce = losses.BinaryCrossentropy(from_logits=False)
mae = losses.MeanAbsoluteError()

def get_gene_loss(fake_output, real_output, fake_disc):
    l1_loss = mae(real_output, fake_output)
    gene_loss = bce(tf.ones_like(fake_disc), fake_disc)
    total_gen_loss = gene_loss + (100 * l1_loss)
    return total_gen_loss, gene_loss, l1_loss

def get_disc_loss(fake_disc, real_disc):
    return bce(tf.zeros_like(fake_disc), fake_disc) + bce(tf.ones_like(real_disc), real_disc)

# %%
from tensorflow.keras import optimizers

gene_opt = optimizers.Adam(2e-4, beta_1=.5, beta_2=.999)
disc_opt = optimizers.Adam(2e-4, beta_1=.5, beta_2=.999)

# %%
generator = UNetGenerator()
discriminator = Discriminator()

@tf.function
def train_step(sketch, real_colored):
    with tf.GradientTape() as gene_tape, tf.GradientTape() as disc_tape:
    # 이전에 배웠던 내용을 토대로 train_step을 구성해주세요.
        # Generator에 Sketch를 입력하여 생성된 이미지를 얻습니다.
        generated_colored = generator(sketch, training=True)

        # Discriminator에 실제 컬러 이미지와 생성된 컬러 이미지를 입력합니다.
        real_disc = discriminator(real_colored, sketch, training=True)
        fake_disc = discriminator(generated_colored, sketch, training=True)

        # Generator의 손실, Loss를 계산합니다.
        total_gen_loss, gene_loss, l1_loss = get_gene_loss(generated_colored, real_colored, fake_disc)

        # Discriminator의 손실을 계산합니다.
        disc_loss = get_disc_loss(fake_disc, real_disc)

    # Generator와 Discriminator의 Gradient를 계산합니다.
    gene_gradient = gene_tape.gradient(total_gen_loss, generator.trainable_variables)
    disc_gradient = disc_tape.gradient(disc_loss, discriminator.trainable_variables)

    gene_opt.apply_gradients(zip(gene_gradient, generator.trainable_variables))
    disc_opt.apply_gradients(zip(disc_gradient, discriminator.trainable_variables))
    return total_gen_loss, l1_loss, disc_loss

# %%
EPOCHS = 50

step_check = []
loss_check = []

for epoch in range(1, EPOCHS+1):
    for i, (sketch, colored) in enumerate(train_images):
        total_gen_loss, l1_loss, d_loss = train_step(sketch, colored)
                
        # 10회 반복마다 손실을 출력합니다.
        if (i+1) % 10 == 0:
            print(f"EPOCH[{epoch}] - STEP[{i+1}] \
                    \nGenerator_loss:{total_gen_loss.numpy():.4f} \
                    \nL1_loss:{l1_loss.numpy():.4f} \
                    \nDiscriminator_loss:{d_loss.numpy():.4f}", end="\n\n")
            
            step_check.append(epoch*(i+1))
            loss_check.append(round(total_gen_loss.numpy(),2))
# Out:
# EPOCH[1] - STEP[10]
# Generator_loss:32.9755
# L1_loss:0.3220
# Discriminator_loss:1.5415
#
# EPOCH[1] - STEP[20]
# Generator_loss:28.8487
# L1_loss:0.2809
# Discriminator_loss:1.5235
#
# EPOCH[1] - STEP[30]
# Generator_loss:26.7448
# L1_loss:0.2598
# Discriminator_loss:1.5303
#
# EPOCH[1] - STEP[40]
# Generator_loss:26.5852
# L1_loss:0.2585
# Discriminator_loss:1.4801
#
# EPOCH[1] - STEP[50]
# Generator_loss:25.6339
# L1_loss:0.2489
# Discriminator_loss:1.5077
#
# EPOCH[1] - STEP[60]
# Generator_loss:25.0065
# L1_loss:0.2426
# Discriminator_loss:1.4991
#
# EPOCH[1] - STEP[70]
# Generator_loss:25.2517
# L1_loss:0.2452
# Discriminator_loss:1.4689
#
# EPOCH[1] - STEP[80]
# Generator_loss:23.8630
# L1_loss:0.2312
# Discriminator_loss:1.4993
#
# EPOCH[1] - STEP[90]
# Generator_loss:26.2182
# L1_loss:0.2547
# Discriminator_loss:1.4921
#
# EPOCH[1] - STEP[100]
# Generator_loss:27.3476
# L1_loss:0.2661
# Discriminator_loss:1.4923
#
# EPOCH[1] - STEP[110]
# Generator_loss:30.5279
# L1_loss:0.2979
# Discriminator_loss:1.4981
#
# EPOCH[1] - STEP[120]
# Generator_loss:23.5997
# L1_loss:0.2287
# Discriminator_loss:1.4656
#
# EPOCH[1] - STEP[130]
# Generator_loss:22.8654
# L1_loss:0.2215
# Discriminator_loss:1.4518
#
# EPOCH[1] - STEP[140]
# Generator_loss:22.2268
# L1_loss:0.2149
# Discriminator_loss:1.4775
#
# EPOCH[1] - STEP[150]
# Generator_loss:20.0294
# L1_loss:0.1931
# Discriminator_loss:1.4625
#
# EPOCH[1] - STEP[160]
# Generator_loss:21.3742
# L1_loss:0.2066
# Discriminator_loss:1.4831
#
# EPOCH[1] - STEP[170]
# Generator_loss:17.7517
# L1_loss:0.1703
# Discriminator_loss:1.4655
#
# EPOCH[1] - STEP[180]
# Generator_loss:24.2878
# L1_loss:0.2357
# Discriminator_loss:1.4561
#
# EPOCH[1] - STEP[190]
# Generator_loss:22.4675
# L1_loss:0.2175
# Discriminator_loss:1.4590
#
# EPOCH[1] - STEP[200]
# Generator_loss:24.5736
# L1_loss:0.2384
# Discriminator_loss:1.4971
#
# EPOCH[1] - STEP[210]
# Generator_loss:24.3077
# L1_loss:0.2358
# Discriminator_loss:1.4811
#
# EPOCH[1] - STEP[220]
# Generator_loss:21.4275
# L1_loss:0.2072
# Discriminator_loss:1.4526
#
# EPOCH[1] - STEP[230]
# Generator_loss:25.5501
# L1_loss:0.2483
# Discriminator_loss:1.4654
#
# EPOCH[1] - STEP[240]
# Generator_loss:23.6005
# L1_loss:0.2288
# Discriminator_loss:1.4740
#
# EPOCH[1] - STEP[250]
# Generator_loss:22.2877
# L1_loss:0.2157
# Discriminator_loss:1.4698
#
# EPOCH[2] - STEP[10]
# Generator_loss:21.7681
# L1_loss:0.2104
# Discriminator_loss:1.4888
#
# EPOCH[2] - STEP[20]
# Generator_loss:28.4804
# L1_loss:0.2777
# Discriminator_loss:1.4620
#
# EPOCH[2] - STEP[30]
# Generator_loss:20.8575
# L1_loss:0.2013
# Discriminator_loss:1.4803
#
# EPOCH[2] - STEP[40]
# Generator_loss:26.2722
# L1_loss:0.2555
# Discriminator_loss:1.4693
#
# EPOCH[2] - STEP[50]
# Generator_loss:23.9852
# L1_loss:0.2327
# Discriminator_loss:1.4661
#
# EPOCH[2] - STEP[60]
# Generator_loss:22.7034
# L1_loss:0.2199
# Discriminator_loss:1.4699
#
# EPOCH[2] - STEP[70]
# Generator_loss:17.7648
# L1_loss:0.1705
# Discriminator_loss:1.4667
#
# EPOCH[2] - STEP[80]
# Generator_loss:20.3056
# L1_loss:0.1959
# Discriminator_loss:1.4648
#
# EPOCH[2] - STEP[90]
# Generator_loss:17.4257
# L1_loss:0.1672
# Discriminator_loss:1.4485
#
# EPOCH[2] - STEP[100]
# Generator_loss:24.2230
# L1_loss:0.2351
# Discriminator_loss:1.4631
#
# EPOCH[2] - STEP[110]
# Generator_loss:21.4411
# L1_loss:0.2075
# Discriminator_loss:1.4286
#
# EPOCH[2] - STEP[120]
# Generator_loss:21.4015
# L1_loss:0.2070
# Discriminator_loss:1.4429
#
# EPOCH[2] - STEP[130]
# Generator_loss:17.9448
# L1_loss:0.1722
# Discriminator_loss:1.4939
#
# EPOCH[2] - STEP[140]
# Generator_loss:20.0402
# L1_loss:0.1933
# Discriminator_loss:1.4663
#
# EPOCH[2] - STEP[150]
# Generator_loss:23.0464
# L1_loss:0.2234
# Discriminator_loss:1.4594
#
# EPOCH[2] - STEP[160]
# Generator_loss:16.2549
# L1_loss:0.1555
# Discriminator_loss:1.4465
#
# EPOCH[2] - STEP[170]
# Generator_loss:20.9581
# L1_loss:0.2025
# Discriminator_loss:1.4647
#
# EPOCH[2] - STEP[180]
# Generator_loss:20.3932
# L1_loss:0.1969
# Discriminator_loss:1.4555
#
# EPOCH[2] - STEP[190]
# Generator_loss:20.6692
# L1_loss:0.1997
# Discriminator_loss:1.4352
#
# EPOCH[2] - STEP[200]
# Generator_loss:20.1999
# L1_loss:0.1950
# Discriminator_loss:1.4508
#
# EPOCH[2] - STEP[210]
# Generator_loss:22.6187
# L1_loss:0.2191
# Discriminator_loss:1.4637
#
# EPOCH[2] - STEP[220]
# Generator_loss:24.8483
# L1_loss:0.2415
# Discriminator_loss:1.4405
#
# EPOCH[2] - STEP[230]
# Generator_loss:18.7799
# L1_loss:0.1808
# Discriminator_loss:1.4553
#
# EPOCH[2] - STEP[240]
# Generator_loss:25.4774
# L1_loss:0.2477
# Discriminator_loss:1.4620
#
# EPOCH[2] - STEP[250]
# Generator_loss:19.8702
# L1_loss:0.1916
# Discriminator_loss:1.4624
#
# EPOCH[3] - STEP[10]
# Generator_loss:18.5012
# L1_loss:0.1780
# Discriminator_loss:1.4436
#
# EPOCH[3] - STEP[20]
# Generator_loss:18.6487
# L1_loss:0.1796
# Discriminator_loss:1.4298
#
# EPOCH[3] - STEP[30]
# Generator_loss:18.2349
# L1_loss:0.1755
# Discriminator_loss:1.4159
#
# EPOCH[3] - STEP[40]
# Generator_loss:20.8580
# L1_loss:0.2016
# Discriminator_loss:1.4434
#
# EPOCH[3] - STEP[50]
# Generator_loss:17.2862
# L1_loss:0.1660
# Discriminator_loss:1.4224
#
# EPOCH[3] - STEP[60]
# Generator_loss:19.7218
# L1_loss:0.1903
# Discriminator_loss:1.4442
#
# EPOCH[3] - STEP[70]
# Generator_loss:22.5410
# L1_loss:0.2183
# Discriminator_loss:1.4600
#
# EPOCH[3] - STEP[80]
# Generator_loss:17.7839
# L1_loss:0.1708
# Discriminator_loss:1.4587
#
# EPOCH[3] - STEP[90]
# Generator_loss:20.1441
# L1_loss:0.1943
# Discriminator_loss:1.4769
#
# EPOCH[3] - STEP[100]
# Generator_loss:21.4550
# L1_loss:0.2076
# Discriminator_loss:1.4312
#
# EPOCH[3] - STEP[110]
# Generator_loss:22.6265
# L1_loss:0.2193
# Discriminator_loss:1.4298
#
# EPOCH[3] - STEP[120]
# Generator_loss:17.7103
# L1_loss:0.1701
# Discriminator_loss:1.4472
#
# EPOCH[3] - STEP[130]
# Generator_loss:17.8040
# L1_loss:0.1711
# Discriminator_loss:1.4447
#
# EPOCH[3] - STEP[140]
# Generator_loss:20.9343
# L1_loss:0.2023
# Discriminator_loss:1.4641
#
# EPOCH[3] - STEP[150]
# Generator_loss:17.9166
# L1_loss:0.1722
# Discriminator_loss:1.4516
#
# EPOCH[3] - STEP[160]
# Generator_loss:18.8075
# L1_loss:0.1811
# Discriminator_loss:1.4403
#
# EPOCH[3] - STEP[170]
# Generator_loss:20.4129
# L1_loss:0.1971
# Discriminator_loss:1.4602
#
# EPOCH[3] - STEP[180]
# Generator_loss:15.2892
# L1_loss:0.1460
# Discriminator_loss:1.4234
#
# EPOCH[3] - STEP[190]
# Generator_loss:16.4168
# L1_loss:0.1573
# Discriminator_loss:1.4181
#
# EPOCH[3] - STEP[200]
# Generator_loss:21.8271
# L1_loss:0.2113
# Discriminator_loss:1.4413
#
# EPOCH[3] - STEP[210]
# Generator_loss:19.1024
# L1_loss:0.1841
# Discriminator_loss:1.4299
#
# EPOCH[3] - STEP[220]
# Generator_loss:18.9588
# L1_loss:0.1825
# Discriminator_loss:1.4640
#
# EPOCH[3] - STEP[230]
# Generator_loss:21.9904
# L1_loss:0.2128
# Discriminator_loss:1.4725
#
# EPOCH[3] - STEP[240]
# Generator_loss:16.2322
# L1_loss:0.1554
# Discriminator_loss:1.4401
#
# EPOCH[3] - STEP[250]
# Generator_loss:18.0498
# L1_loss:0.1736
# Discriminator_loss:1.4267
#
# EPOCH[4] - STEP[10]
# Generator_loss:17.5990
# L1_loss:0.1690
# Discriminator_loss:1.4496
#
# EPOCH[4] - STEP[20]
# Generator_loss:19.8312
# L1_loss:0.1914
# Discriminator_loss:1.4383
#
# EPOCH[4] - STEP[30]
# Generator_loss:20.6355
# L1_loss:0.1993
# Discriminator_loss:1.4585
#
# EPOCH[4] - STEP[40]
# Generator_loss:18.2266
# L1_loss:0.1753
# Discriminator_loss:1.4313
#
# EPOCH[4] - STEP[50]
# Generator_loss:26.5780
# L1_loss:0.2589
# Discriminator_loss:1.4247
#
# EPOCH[4] - STEP[60]
# Generator_loss:18.0162
# L1_loss:0.1732
# Discriminator_loss:1.4398
#
# EPOCH[4] - STEP[70]
# Generator_loss:20.9671
# L1_loss:0.2028
# Discriminator_loss:1.4213
#
# EPOCH[4] - STEP[80]
# Generator_loss:19.3807
# L1_loss:0.1869
# Discriminator_loss:1.4337
#
# EPOCH[4] - STEP[90]
# Generator_loss:19.8206
# L1_loss:0.1913
# Discriminator_loss:1.4290
#
# EPOCH[4] - STEP[100]
# Generator_loss:15.3510
# L1_loss:0.1466
# Discriminator_loss:1.4278
#
# EPOCH[4] - STEP[110]
# Generator_loss:20.5510
# L1_loss:0.1986
# Discriminator_loss:1.4219
#
# EPOCH[4] - STEP[120]
# Generator_loss:18.2274
# L1_loss:0.1752
# Discriminator_loss:1.4515
#
# EPOCH[4] - STEP[130]
# Generator_loss:19.7668
# L1_loss:0.1907
# Discriminator_loss:1.4395
#
# EPOCH[4] - STEP[140]
# Generator_loss:17.0313
# L1_loss:0.1634
# Discriminator_loss:1.4280
#
# EPOCH[4] - STEP[150]
# Generator_loss:24.9681
# L1_loss:0.2428
# Discriminator_loss:1.4266
#
# EPOCH[4] - STEP[160]
# Generator_loss:22.0461
# L1_loss:0.2136
# Discriminator_loss:1.4214
#
# EPOCH[4] - STEP[170]
# Generator_loss:18.6976
# L1_loss:0.1800
# Discriminator_loss:1.4279
#
# EPOCH[4] - STEP[180]
# Generator_loss:19.1916
# L1_loss:0.1851
# Discriminator_loss:1.4091
#
# EPOCH[4] - STEP[190]
# Generator_loss:18.9037
# L1_loss:0.1819
# Discriminator_loss:1.4582
#
# EPOCH[4] - STEP[200]
# Generator_loss:18.6829
# L1_loss:0.1799
# Discriminator_loss:1.4263
#
# EPOCH[4] - STEP[210]
# Generator_loss:18.7589
# L1_loss:0.1805
# Discriminator_loss:1.4554
#
# EPOCH[4] - STEP[220]
# Generator_loss:19.6621
# L1_loss:0.1897
# Discriminator_loss:1.4201
#
# EPOCH[4] - STEP[230]
# Generator_loss:16.8822
# L1_loss:0.1617
# Discriminator_loss:1.4548
#
# EPOCH[4] - STEP[240]
# Generator_loss:17.9359
# L1_loss:0.1724
# Discriminator_loss:1.4213
#
# EPOCH[4] - STEP[250]
# Generator_loss:15.7068
# L1_loss:0.1502
# Discriminator_loss:1.4114
#
# EPOCH[5] - STEP[10]
# Generator_loss:17.2565
# L1_loss:0.1655
# Discriminator_loss:1.4467
#
# EPOCH[5] - STEP[20]
# Generator_loss:18.9507
# L1_loss:0.1826
# Discriminator_loss:1.4241
#
# EPOCH[5] - STEP[30]
# Generator_loss:13.5047
# L1_loss:0.1277
# Discriminator_loss:1.4704
#
# EPOCH[5] - STEP[40]
# Generator_loss:17.5759
# L1_loss:0.1688
# Discriminator_loss:1.4255
#
# EPOCH[5] - STEP[50]
# Generator_loss:18.2193
# L1_loss:0.1751
# Discriminator_loss:1.4573
#
# EPOCH[5] - STEP[60]
# Generator_loss:17.2342
# L1_loss:0.1654
# Discriminator_loss:1.4274
#
# EPOCH[5] - STEP[70]
# Generator_loss:16.6967
# L1_loss:0.1601
# Discriminator_loss:1.4202
#
# EPOCH[5] - STEP[80]
# Generator_loss:16.6990
# L1_loss:0.1600
# Discriminator_loss:1.4277
#
# EPOCH[5] - STEP[90]
# Generator_loss:15.4751
# L1_loss:0.1478
# Discriminator_loss:1.4216
#
# EPOCH[5] - STEP[100]
# Generator_loss:21.4743
# L1_loss:0.2078
# Discriminator_loss:1.4230
#
# EPOCH[5] - STEP[110]
# Generator_loss:19.9348
# L1_loss:0.1925
# Discriminator_loss:1.4114
#
# EPOCH[5] - STEP[120]
# Generator_loss:20.3040
# L1_loss:0.1961
# Discriminator_loss:1.4323
#
# EPOCH[5] - STEP[130]
# Generator_loss:19.9870
# L1_loss:0.1924
# Discriminator_loss:1.4664
#
# EPOCH[5] - STEP[140]
# Generator_loss:17.3924
# L1_loss:0.1670
# Discriminator_loss:1.4206
#
# EPOCH[5] - STEP[150]
# Generator_loss:21.9745
# L1_loss:0.2128
# Discriminator_loss:1.4228
#
# EPOCH[5] - STEP[160]
# Generator_loss:17.7321
# L1_loss:0.1704
# Discriminator_loss:1.4140
#
# EPOCH[5] - STEP[170]
# Generator_loss:16.2169
# L1_loss:0.1551
# Discriminator_loss:1.4503
#
# EPOCH[5] - STEP[180]
# Generator_loss:14.3022
# L1_loss:0.1361
# Discriminator_loss:1.4236
#
# EPOCH[5] - STEP[190]
# Generator_loss:15.6970
# L1_loss:0.1500
# Discriminator_loss:1.4285
#
# EPOCH[5] - STEP[200]
# Generator_loss:16.3167
# L1_loss:0.1561
# Discriminator_loss:1.4471
#
# EPOCH[5] - STEP[210]
# Generator_loss:17.2554
# L1_loss:0.1656
# Discriminator_loss:1.4239
#
# EPOCH[5] - STEP[220]
# Generator_loss:24.2125
# L1_loss:0.2351
# Discriminator_loss:1.4381
#
# EPOCH[5] - STEP[230]
# Generator_loss:19.5373
# L1_loss:0.1885
# Discriminator_loss:1.4141
#
# EPOCH[5] - STEP[240]
# Generator_loss:21.0947
# L1_loss:0.2040
# Discriminator_loss:1.4279
#
# EPOCH[5] - STEP[250]
# Generator_loss:23.5192
# L1_loss:0.2282
# Discriminator_loss:1.4279
#
# EPOCH[6] - STEP[10]
# Generator_loss:17.8567
# L1_loss:0.1716
# Discriminator_loss:1.4251
#
# EPOCH[6] - STEP[20]
# Generator_loss:17.6788
# L1_loss:0.1699
# Discriminator_loss:1.4199
#
# EPOCH[6] - STEP[30]
# Generator_loss:17.5789
# L1_loss:0.1689
# Discriminator_loss:1.4095
#
# EPOCH[6] - STEP[40]
# Generator_loss:23.2194
# L1_loss:0.2252
# Discriminator_loss:1.4272
#
# EPOCH[6] - STEP[50]
# Generator_loss:16.7310
# L1_loss:0.1604
# Discriminator_loss:1.4195
#
# EPOCH[6] - STEP[60]
# Generator_loss:18.1967
# L1_loss:0.1751
# Discriminator_loss:1.4127
#
# EPOCH[6] - STEP[70]
# Generator_loss:18.3615
# L1_loss:0.1766
# Discriminator_loss:1.4274
#
# EPOCH[6] - STEP[80]
# Generator_loss:17.9591
# L1_loss:0.1727
# Discriminator_loss:1.4125
#
# EPOCH[6] - STEP[90]
# Generator_loss:15.9140
# L1_loss:0.1521
# Discriminator_loss:1.4434
#
# EPOCH[6] - STEP[100]
# Generator_loss:20.0584
# L1_loss:0.1937
# Discriminator_loss:1.4181
#
# EPOCH[6] - STEP[110]
# Generator_loss:14.2555
# L1_loss:0.1355
# Discriminator_loss:1.4354
#
# EPOCH[6] - STEP[120]
# Generator_loss:17.2303
# L1_loss:0.1654
# Discriminator_loss:1.4171
#
# EPOCH[6] - STEP[130]
# Generator_loss:13.6503
# L1_loss:0.1294
# Discriminator_loss:1.4413
#
# EPOCH[6] - STEP[140]
# Generator_loss:21.0639
# L1_loss:0.2037
# Discriminator_loss:1.4288
#
# EPOCH[6] - STEP[150]
# Generator_loss:20.1363
# L1_loss:0.1944
# Discriminator_loss:1.4270
#
# EPOCH[6] - STEP[160]
# Generator_loss:16.9741
# L1_loss:0.1628
# Discriminator_loss:1.4300
#
# EPOCH[6] - STEP[170]
# Generator_loss:17.7547
# L1_loss:0.1706
# Discriminator_loss:1.4249
#
# EPOCH[6] - STEP[180]
# Generator_loss:14.9290
# L1_loss:0.1423
# Discriminator_loss:1.4301
#
# EPOCH[6] - STEP[190]
# Generator_loss:21.2924
# L1_loss:0.2060
# Discriminator_loss:1.4200
#
# EPOCH[6] - STEP[200]
# Generator_loss:16.6595
# L1_loss:0.1597
# Discriminator_loss:1.4142
#
# EPOCH[6] - STEP[210]
# Generator_loss:15.8259
# L1_loss:0.1514
# Discriminator_loss:1.4430
#
# EPOCH[6] - STEP[220]
# Generator_loss:18.8556
# L1_loss:0.1816
# Discriminator_loss:1.4186
#
# EPOCH[6] - STEP[230]
# Generator_loss:18.0918
# L1_loss:0.1740
# Discriminator_loss:1.4157
#
# EPOCH[6] - STEP[240]
# Generator_loss:13.5994
# L1_loss:0.1289
# Discriminator_loss:1.4473
#
# EPOCH[6] - STEP[250]
# Generator_loss:14.5919
# L1_loss:0.1390
# Discriminator_loss:1.4210
#
# EPOCH[7] - STEP[10]
# Generator_loss:20.9567
# L1_loss:0.2026
# Discriminator_loss:1.4250
#
# EPOCH[7] - STEP[20]
# Generator_loss:16.3507
# L1_loss:0.1566
# Discriminator_loss:1.4173
#
# EPOCH[7] - STEP[30]
# Generator_loss:14.0193
# L1_loss:0.1332
# Discriminator_loss:1.4264
#
# EPOCH[7] - STEP[40]
# Generator_loss:21.2527
# L1_loss:0.2056
# Discriminator_loss:1.4203
#
# EPOCH[7] - STEP[50]
# Generator_loss:17.5761
# L1_loss:0.1687
# Discriminator_loss:1.4667
#
# EPOCH[7] - STEP[60]
# Generator_loss:15.4309
# L1_loss:0.1473
# Discriminator_loss:1.4262
#
# EPOCH[7] - STEP[70]
# Generator_loss:16.8285
# L1_loss:0.1613
# Discriminator_loss:1.4259
#
# EPOCH[7] - STEP[80]
# Generator_loss:15.9031
# L1_loss:0.1522
# Discriminator_loss:1.4108
#
# EPOCH[7] - STEP[90]
# Generator_loss:15.6406
# L1_loss:0.1495
# Discriminator_loss:1.4163
#
# EPOCH[7] - STEP[100]
# Generator_loss:16.8410
# L1_loss:0.1615
# Discriminator_loss:1.4133
#
# EPOCH[7] - STEP[110]
# Generator_loss:17.6118
# L1_loss:0.1691
# Discriminator_loss:1.4369
#
# EPOCH[7] - STEP[120]
# Generator_loss:17.7823
# L1_loss:0.1708
# Discriminator_loss:1.4251
#
# EPOCH[7] - STEP[130]
# Generator_loss:16.4575
# L1_loss:0.1576
# Discriminator_loss:1.4206
#
# EPOCH[7] - STEP[140]
# Generator_loss:21.0477
# L1_loss:0.2035
# Discriminator_loss:1.4335
#
# EPOCH[7] - STEP[150]
# Generator_loss:18.5109
# L1_loss:0.1782
# Discriminator_loss:1.4152
#
# EPOCH[7] - STEP[160]
# Generator_loss:18.2224
# L1_loss:0.1752
# Discriminator_loss:1.4320
#
# EPOCH[7] - STEP[170]
# Generator_loss:16.3362
# L1_loss:0.1564
# Discriminator_loss:1.4215
#
# EPOCH[7] - STEP[180]
# Generator_loss:23.5396
# L1_loss:0.2284
# Discriminator_loss:1.4260
#
# EPOCH[7] - STEP[190]
# Generator_loss:18.2627
# L1_loss:0.1757
# Discriminator_loss:1.4210
#
# EPOCH[7] - STEP[200]
# Generator_loss:14.3657
# L1_loss:0.1366
# Discriminator_loss:1.4431
#
# EPOCH[7] - STEP[210]
# Generator_loss:22.7683
# L1_loss:0.2206
# Discriminator_loss:1.4436
#
# EPOCH[7] - STEP[220]
# Generator_loss:15.5147
# L1_loss:0.1482
# Discriminator_loss:1.4159
#
# EPOCH[7] - STEP[230]
# Generator_loss:19.0078
# L1_loss:0.1831
# Discriminator_loss:1.4183
#
# EPOCH[7] - STEP[240]
# Generator_loss:19.6153
# L1_loss:0.1892
# Discriminator_loss:1.4208
#
# EPOCH[7] - STEP[250]
# Generator_loss:17.1391
# L1_loss:0.1643
# Discriminator_loss:1.4458
#
# EPOCH[8] - STEP[10]
# Generator_loss:15.9369
# L1_loss:0.1525
# Discriminator_loss:1.4149
#
# EPOCH[8] - STEP[20]
# Generator_loss:14.2790
# L1_loss:0.1359
# Discriminator_loss:1.4086
#
# EPOCH[8] - STEP[30]
# Generator_loss:18.5332
# L1_loss:0.1783
# Discriminator_loss:1.4312
#
# EPOCH[8] - STEP[40]
# Generator_loss:17.7491
# L1_loss:0.1706
# Discriminator_loss:1.4156
#
# EPOCH[8] - STEP[50]
# Generator_loss:15.9842
# L1_loss:0.1529
# Discriminator_loss:1.4209
#
# EPOCH[8] - STEP[60]
# Generator_loss:17.6003
# L1_loss:0.1691
# Discriminator_loss:1.4136
#
# EPOCH[8] - STEP[70]
# Generator_loss:18.6660
# L1_loss:0.1797
# Discriminator_loss:1.4312
#
# EPOCH[8] - STEP[80]
# Generator_loss:18.8694
# L1_loss:0.1818
# Discriminator_loss:1.4156
#
# EPOCH[8] - STEP[90]
# Generator_loss:19.1709
# L1_loss:0.1848
# Discriminator_loss:1.4113
#
# EPOCH[8] - STEP[100]
# Generator_loss:16.7008
# L1_loss:0.1600
# Discriminator_loss:1.4311
#
# EPOCH[8] - STEP[110]
# Generator_loss:17.3846
# L1_loss:0.1670
# Discriminator_loss:1.4042
#
# EPOCH[8] - STEP[120]
# Generator_loss:17.0945
# L1_loss:0.1641
# Discriminator_loss:1.4078
#
# EPOCH[8] - STEP[130]
# Generator_loss:22.9541
# L1_loss:0.2226
# Discriminator_loss:1.4098
#
# EPOCH[8] - STEP[140]
# Generator_loss:16.0216
# L1_loss:0.1533
# Discriminator_loss:1.4115
#
# EPOCH[8] - STEP[150]
# Generator_loss:19.4829
# L1_loss:0.1879
# Discriminator_loss:1.4204
#
# EPOCH[8] - STEP[160]
# Generator_loss:14.7424
# L1_loss:0.1405
# Discriminator_loss:1.4073
#
# EPOCH[8] - STEP[170]
# Generator_loss:15.8481
# L1_loss:0.1514
# Discriminator_loss:1.4417
#
# EPOCH[8] - STEP[180]
# Generator_loss:15.1470
# L1_loss:0.1446
# Discriminator_loss:1.4111
#
# EPOCH[8] - STEP[190]
# Generator_loss:16.9531
# L1_loss:0.1625
# Discriminator_loss:1.4414
#
# EPOCH[8] - STEP[200]
# Generator_loss:16.1482
# L1_loss:0.1544
# Discriminator_loss:1.4447
#
# EPOCH[8] - STEP[210]
# Generator_loss:16.7926
# L1_loss:0.1610
# Discriminator_loss:1.4087
#
# EPOCH[8] - STEP[220]
# Generator_loss:15.3166
# L1_loss:0.1461
# Discriminator_loss:1.4469
#
# EPOCH[8] - STEP[230]
# Generator_loss:15.6966
# L1_loss:0.1501
# Discriminator_loss:1.4138
#
# EPOCH[8] - STEP[240]
# Generator_loss:17.9620
# L1_loss:0.1727
# Discriminator_loss:1.4057
#
# EPOCH[8] - STEP[250]
# Generator_loss:21.5998
# L1_loss:0.2091
# Discriminator_loss:1.4172
#
# EPOCH[9] - STEP[10]
# Generator_loss:14.7574
# L1_loss:0.1406
# Discriminator_loss:1.4146
#
# EPOCH[9] - STEP[20]
# Generator_loss:19.5027
# L1_loss:0.1880
# Discriminator_loss:1.4355
#
# EPOCH[9] - STEP[30]
# Generator_loss:16.6796
# L1_loss:0.1599
# Discriminator_loss:1.4123
#
# EPOCH[9] - STEP[40]
# Generator_loss:15.1588
# L1_loss:0.1447
# Discriminator_loss:1.4076
#
# EPOCH[9] - STEP[50]
# Generator_loss:16.9458
# L1_loss:0.1625
# Discriminator_loss:1.4112
#
# EPOCH[9] - STEP[60]
# Generator_loss:15.0073
# L1_loss:0.1432
# Discriminator_loss:1.4071
#
# EPOCH[9] - STEP[70]
# Generator_loss:15.0956
# L1_loss:0.1440
# Discriminator_loss:1.4089
#
# EPOCH[9] - STEP[80]
# Generator_loss:16.9142
# L1_loss:0.1622
# Discriminator_loss:1.4114
#
# EPOCH[9] - STEP[90]
# Generator_loss:14.0565
# L1_loss:0.1336
# Discriminator_loss:1.4152
#
# EPOCH[9] - STEP[100]
# Generator_loss:14.1897
# L1_loss:0.1349
# Discriminator_loss:1.4189
#
# EPOCH[9] - STEP[110]
# Generator_loss:14.8180
# L1_loss:0.1412
# Discriminator_loss:1.4149
#
# EPOCH[9] - STEP[120]
# Generator_loss:15.7267
# L1_loss:0.1503
# Discriminator_loss:1.4176
#
# EPOCH[9] - STEP[130]
# Generator_loss:14.1642
# L1_loss:0.1347
# Discriminator_loss:1.4221
#
# EPOCH[9] - STEP[140]
# Generator_loss:24.2327
# L1_loss:0.2354
# Discriminator_loss:1.4047
#
# EPOCH[9] - STEP[150]
# Generator_loss:16.2555
# L1_loss:0.1556
# Discriminator_loss:1.4114
#
# EPOCH[9] - STEP[160]
# Generator_loss:14.9407
# L1_loss:0.1425
# Discriminator_loss:1.4104
#
# EPOCH[9] - STEP[170]
# Generator_loss:14.9752
# L1_loss:0.1428
# Discriminator_loss:1.4089
#
# EPOCH[9] - STEP[180]
# Generator_loss:15.8960
# L1_loss:0.1521
# Discriminator_loss:1.4048
#
# EPOCH[9] - STEP[190]
# Generator_loss:15.5999
# L1_loss:0.1489
# Discriminator_loss:1.4392
#
# EPOCH[9] - STEP[200]
# Generator_loss:16.9769
# L1_loss:0.1628
# Discriminator_loss:1.4096
#
# EPOCH[9] - STEP[210]
# Generator_loss:19.0974
# L1_loss:0.1841
# Discriminator_loss:1.4116
#
# EPOCH[9] - STEP[220]
# Generator_loss:16.7665
# L1_loss:0.1607
# Discriminator_loss:1.4125
#
# EPOCH[9] - STEP[230]
# Generator_loss:20.7619
# L1_loss:0.2007
# Discriminator_loss:1.4134
#
# EPOCH[9] - STEP[240]
# Generator_loss:13.6089
# L1_loss:0.1291
# Discriminator_loss:1.4251
#
# EPOCH[9] - STEP[250]
# Generator_loss:15.5636
# L1_loss:0.1487
# Discriminator_loss:1.4124
#
# EPOCH[10] - STEP[10]
# Generator_loss:18.3384
# L1_loss:0.1764
# Discriminator_loss:1.4108
#
# EPOCH[10] - STEP[20]
# Generator_loss:17.0524
# L1_loss:0.1636
# Discriminator_loss:1.4102
#
# EPOCH[10] - STEP[30]
# Generator_loss:16.3505
# L1_loss:0.1566
# Discriminator_loss:1.4121
#
# EPOCH[10] - STEP[40]
# Generator_loss:17.8154
# L1_loss:0.1712
# Discriminator_loss:1.4140
#
# EPOCH[10] - STEP[50]
# Generator_loss:17.6969
# L1_loss:0.1700
# Discriminator_loss:1.4092
#
# EPOCH[10] - STEP[60]
# Generator_loss:15.6719
# L1_loss:0.1498
# Discriminator_loss:1.4099
#
# EPOCH[10] - STEP[70]
# Generator_loss:14.6079
# L1_loss:0.1391
# Discriminator_loss:1.4106
#
# EPOCH[10] - STEP[80]
# Generator_loss:14.4646
# L1_loss:0.1377
# Discriminator_loss:1.4112
#
# EPOCH[10] - STEP[90]
# Generator_loss:16.3124
# L1_loss:0.1558
# Discriminator_loss:1.4761
#
# EPOCH[10] - STEP[100]
# Generator_loss:17.2144
# L1_loss:0.1652
# Discriminator_loss:1.4110
#
# EPOCH[10] - STEP[110]
# Generator_loss:17.9295
# L1_loss:0.1724
# Discriminator_loss:1.4085
#
# EPOCH[10] - STEP[120]
# Generator_loss:17.7713
# L1_loss:0.1707
# Discriminator_loss:1.4170
#
# EPOCH[10] - STEP[130]
# Generator_loss:14.3422
# L1_loss:0.1365
# Discriminator_loss:1.4041
#
# EPOCH[10] - STEP[140]
# Generator_loss:20.6219
# L1_loss:0.1993
# Discriminator_loss:1.4054
#
# EPOCH[10] - STEP[150]
# Generator_loss:17.6639
# L1_loss:0.1697
# Discriminator_loss:1.4149
#
# EPOCH[10] - STEP[160]
# Generator_loss:17.4841
# L1_loss:0.1679
# Discriminator_loss:1.4130
#
# EPOCH[10] - STEP[170]
# Generator_loss:15.2362
# L1_loss:0.1454
# Discriminator_loss:1.4132
#
# EPOCH[10] - STEP[180]
# Generator_loss:21.7548
# L1_loss:0.2106
# Discriminator_loss:1.4054
#
# EPOCH[10] - STEP[190]
# Generator_loss:16.6868
# L1_loss:0.1600
# Discriminator_loss:1.4045
#
# EPOCH[10] - STEP[200]
# Generator_loss:18.5739
# L1_loss:0.1788
# Discriminator_loss:1.4130
#
# EPOCH[10] - STEP[210]
# Generator_loss:19.1523
# L1_loss:0.1846
# Discriminator_loss:1.4060
#
# EPOCH[10] - STEP[220]
# Generator_loss:16.5031
# L1_loss:0.1581
# Discriminator_loss:1.4106
#
# EPOCH[10] - STEP[230]
# Generator_loss:17.2689
# L1_loss:0.1657
# Discriminator_loss:1.4163
#
# EPOCH[10] - STEP[240]
# Generator_loss:14.8947
# L1_loss:0.1420
# Discriminator_loss:1.4051
#
# EPOCH[10] - STEP[250]
# Generator_loss:15.8621
# L1_loss:0.1517
# Discriminator_loss:1.4065
#
# EPOCH[11] - STEP[10]
# Generator_loss:16.5563
# L1_loss:0.1586
# Discriminator_loss:1.4032
#
# EPOCH[11] - STEP[20]
# Generator_loss:15.5750
# L1_loss:0.1488
# Discriminator_loss:1.4109
#
# EPOCH[11] - STEP[30]
# Generator_loss:14.4837
# L1_loss:0.1379
# Discriminator_loss:1.4077
#
# EPOCH[11] - STEP[40]
# Generator_loss:21.0913
# L1_loss:0.2040
# Discriminator_loss:1.4069
#
# EPOCH[11] - STEP[50]
# Generator_loss:15.8257
# L1_loss:0.1513
# Discriminator_loss:1.4203
#
# EPOCH[11] - STEP[60]
# Generator_loss:16.7406
# L1_loss:0.1605
# Discriminator_loss:1.4059
#
# EPOCH[11] - STEP[70]
# Generator_loss:17.8930
# L1_loss:0.1720
# Discriminator_loss:1.4070
#
# EPOCH[11] - STEP[80]
# Generator_loss:17.2526
# L1_loss:0.1656
# Discriminator_loss:1.4088
#
# EPOCH[11] - STEP[90]
# Generator_loss:18.6311
# L1_loss:0.1794
# Discriminator_loss:1.4062
#
# EPOCH[11] - STEP[100]
# Generator_loss:16.3214
# L1_loss:0.1563
# Discriminator_loss:1.4090
#
# EPOCH[11] - STEP[110]
# Generator_loss:14.0088
# L1_loss:0.1332
# Discriminator_loss:1.4037
#
# EPOCH[11] - STEP[120]
# Generator_loss:15.0657
# L1_loss:0.1437
# Discriminator_loss:1.4078
#
# EPOCH[11] - STEP[130]
# Generator_loss:18.8055
# L1_loss:0.1811
# Discriminator_loss:1.4094
#
# EPOCH[11] - STEP[140]
# Generator_loss:20.4125
# L1_loss:0.1972
# Discriminator_loss:1.4072
#
# EPOCH[11] - STEP[150]
# Generator_loss:16.1006
# L1_loss:0.1541
# Discriminator_loss:1.4073
#
# EPOCH[11] - STEP[160]
# Generator_loss:14.2937
# L1_loss:0.1360
# Discriminator_loss:1.4132
#
# EPOCH[11] - STEP[170]
# Generator_loss:14.1562
# L1_loss:0.1346
# Discriminator_loss:1.4092
#
# EPOCH[11] - STEP[180]
# Generator_loss:15.1108
# L1_loss:0.1441
# Discriminator_loss:1.4140
#
# EPOCH[11] - STEP[190]
# Generator_loss:14.2906
# L1_loss:0.1360
# Discriminator_loss:1.4079
#
# EPOCH[11] - STEP[200]
# Generator_loss:16.7582
# L1_loss:0.1607
# Discriminator_loss:1.3996
#
# EPOCH[11] - STEP[210]
# Generator_loss:15.7758
# L1_loss:0.1508
# Discriminator_loss:1.4004
#
# EPOCH[11] - STEP[220]
# Generator_loss:20.0859
# L1_loss:0.1939
# Discriminator_loss:1.4083
#
# EPOCH[11] - STEP[230]
# Generator_loss:15.0769
# L1_loss:0.1438
# Discriminator_loss:1.4094
#
# EPOCH[11] - STEP[240]
# Generator_loss:16.8237
# L1_loss:0.1613
# Discriminator_loss:1.4123
#
# EPOCH[11] - STEP[250]
# Generator_loss:15.2187
# L1_loss:0.1453
# Discriminator_loss:1.3983
#
# EPOCH[12] - STEP[10]
# Generator_loss:14.2215
# L1_loss:0.1353
# Discriminator_loss:1.4071
#
# EPOCH[12] - STEP[20]
# Generator_loss:15.9216
# L1_loss:0.1523
# Discriminator_loss:1.3990
#
# EPOCH[12] - STEP[30]
# Generator_loss:16.5988
# L1_loss:0.1590
# Discriminator_loss:1.4099
#
# EPOCH[12] - STEP[40]
# Generator_loss:10.6303
# L1_loss:0.0991
# Discriminator_loss:1.4369
#
# EPOCH[12] - STEP[50]
# Generator_loss:16.9605
# L1_loss:0.1627
# Discriminator_loss:1.4115
#
# EPOCH[12] - STEP[60]
# Generator_loss:14.2009
# L1_loss:0.1351
# Discriminator_loss:1.4049
#
# EPOCH[12] - STEP[70]
# Generator_loss:17.9644
# L1_loss:0.1727
# Discriminator_loss:1.4038
#
# EPOCH[12] - STEP[80]
# Generator_loss:13.2283
# L1_loss:0.1253
# Discriminator_loss:1.4168
#
# EPOCH[12] - STEP[90]
# Generator_loss:16.8416
# L1_loss:0.1615
# Discriminator_loss:1.4035
#
# EPOCH[12] - STEP[100]
# Generator_loss:15.8368
# L1_loss:0.1514
# Discriminator_loss:1.4035
#
# EPOCH[12] - STEP[110]
# Generator_loss:13.1067
# L1_loss:0.1242
# Discriminator_loss:1.3997
#
# EPOCH[12] - STEP[120]
# Generator_loss:18.9785
# L1_loss:0.1828
# Discriminator_loss:1.4097
#
# EPOCH[12] - STEP[130]
# Generator_loss:16.9879
# L1_loss:0.1629
# Discriminator_loss:1.4092
#
# EPOCH[12] - STEP[140]
# Generator_loss:12.7907
# L1_loss:0.1210
# Discriminator_loss:1.3997
#
# EPOCH[12] - STEP[150]
# Generator_loss:19.0303
# L1_loss:0.1834
# Discriminator_loss:1.4031
#
# EPOCH[12] - STEP[160]
# Generator_loss:20.4700
# L1_loss:0.1977
# Discriminator_loss:1.4137
#
# EPOCH[12] - STEP[170]
# Generator_loss:19.2778
# L1_loss:0.1858
# Discriminator_loss:1.4110
#
# EPOCH[12] - STEP[180]
# Generator_loss:13.8226
# L1_loss:0.1313
# Discriminator_loss:1.4089
#
# EPOCH[12] - STEP[190]
# Generator_loss:15.7664
# L1_loss:0.1507
# Discriminator_loss:1.4099
#
# EPOCH[12] - STEP[200]
# Generator_loss:16.2275
# L1_loss:0.1553
# Discriminator_loss:1.4033
#
# EPOCH[12] - STEP[210]
# Generator_loss:17.7434
# L1_loss:0.1705
# Discriminator_loss:1.4037
#
# EPOCH[12] - STEP[220]
# Generator_loss:18.1117
# L1_loss:0.1742
# Discriminator_loss:1.4022
#
# EPOCH[12] - STEP[230]
# Generator_loss:18.3323
# L1_loss:0.1763
# Discriminator_loss:1.4122
#
# EPOCH[12] - STEP[240]
# Generator_loss:15.9346
# L1_loss:0.1524
# Discriminator_loss:1.3987
#
# EPOCH[12] - STEP[250]
# Generator_loss:14.0307
# L1_loss:0.1334
# Discriminator_loss:1.4075
#
# EPOCH[13] - STEP[10]
# Generator_loss:15.4665
# L1_loss:0.1477
# Discriminator_loss:1.4031
#
# EPOCH[13] - STEP[20]
# Generator_loss:13.8155
# L1_loss:0.1313
# Discriminator_loss:1.3987
#
# EPOCH[13] - STEP[30]
# Generator_loss:16.0718
# L1_loss:0.1538
# Discriminator_loss:1.4030
#
# EPOCH[13] - STEP[40]
# Generator_loss:16.1393
# L1_loss:0.1544
# Discriminator_loss:1.4143
#
# EPOCH[13] - STEP[50]
# Generator_loss:16.5658
# L1_loss:0.1587
# Discriminator_loss:1.4062
#
# EPOCH[13] - STEP[60]
# Generator_loss:18.5124
# L1_loss:0.1782
# Discriminator_loss:1.3992
#
# EPOCH[13] - STEP[70]
# Generator_loss:14.6921
# L1_loss:0.1400
# Discriminator_loss:1.4020
#
# EPOCH[13] - STEP[80]
# Generator_loss:15.1081
# L1_loss:0.1441
# Discriminator_loss:1.4082
#
# EPOCH[13] - STEP[90]
# Generator_loss:15.9440
# L1_loss:0.1525
# Discriminator_loss:1.4085
#
# EPOCH[13] - STEP[100]
# Generator_loss:15.2874
# L1_loss:0.1459
# Discriminator_loss:1.4082
#
# EPOCH[13] - STEP[110]
# Generator_loss:15.4309
# L1_loss:0.1474
# Discriminator_loss:1.4075
#
# EPOCH[13] - STEP[120]
# Generator_loss:17.9730
# L1_loss:0.1727
# Discriminator_loss:1.4156
#
# EPOCH[13] - STEP[130]
# Generator_loss:18.4480
# L1_loss:0.1776
# Discriminator_loss:1.3979
#
# EPOCH[13] - STEP[140]
# Generator_loss:12.8192
# L1_loss:0.1213
# Discriminator_loss:1.3993
#
# EPOCH[13] - STEP[150]
# Generator_loss:13.6584
# L1_loss:0.1296
# Discriminator_loss:1.4078
#
# EPOCH[13] - STEP[160]
# Generator_loss:12.3630
# L1_loss:0.1167
# Discriminator_loss:1.4045
#
# EPOCH[13] - STEP[170]
# Generator_loss:13.9747
# L1_loss:0.1328
# Discriminator_loss:1.3995
#
# EPOCH[13] - STEP[180]
# Generator_loss:14.4114
# L1_loss:0.1370
# Discriminator_loss:1.4483
#
# EPOCH[13] - STEP[190]
# Generator_loss:19.4236
# L1_loss:0.1873
# Discriminator_loss:1.4090
#
# EPOCH[13] - STEP[200]
# Generator_loss:15.9455
# L1_loss:0.1525
# Discriminator_loss:1.4065
#
# EPOCH[13] - STEP[210]
# Generator_loss:17.9602
# L1_loss:0.1727
# Discriminator_loss:1.4070
#
# EPOCH[13] - STEP[220]
# Generator_loss:16.2387
# L1_loss:0.1554
# Discriminator_loss:1.4051
#
# ...
# Generator_loss:9.7178
# L1_loss:0.0902
# Discriminator_loss:1.3863
#
# EPOCH[46] - STEP[200]
# Generator_loss:12.6238
# L1_loss:0.1193
# Discriminator_loss:1.3863
#
# EPOCH[46] - STEP[210]
# Generator_loss:12.7926
# L1_loss:0.1210
# Discriminator_loss:1.3863
#
# EPOCH[46] - STEP[220]
# Generator_loss:11.2060
# L1_loss:0.1051
# Discriminator_loss:1.3863
#
# EPOCH[46] - STEP[230]
# Generator_loss:12.6569
# L1_loss:0.1196
# Discriminator_loss:1.3863
#
# EPOCH[46] - STEP[240]
# Generator_loss:11.9843
# L1_loss:0.1129
# Discriminator_loss:1.3863
#
# EPOCH[46] - STEP[250]
# Generator_loss:10.6071
# L1_loss:0.0991
# Discriminator_loss:1.3863
#
# EPOCH[47] - STEP[10]
# Generator_loss:15.1764
# L1_loss:0.1448
# Discriminator_loss:1.3863
#
# EPOCH[47] - STEP[20]
# Generator_loss:14.2925
# L1_loss:0.1360
# Discriminator_loss:1.3863
#
# EPOCH[47] - STEP[30]
# Generator_loss:10.3265
# L1_loss:0.0963
# Discriminator_loss:1.3863
#
# EPOCH[47] - STEP[40]
# Generator_loss:12.2129
# L1_loss:0.1152
# Discriminator_loss:1.3863
#
# EPOCH[47] - STEP[50]
# Generator_loss:11.0699
# L1_loss:0.1038
# Discriminator_loss:1.3863
#
# EPOCH[47] - STEP[60]
# Generator_loss:10.2396
# L1_loss:0.0955
# Discriminator_loss:1.3863
#
# EPOCH[47] - STEP[70]
# Generator_loss:10.1310
# L1_loss:0.0944
# Discriminator_loss:1.3863
#
# EPOCH[47] - STEP[80]
# Generator_loss:9.8223
# L1_loss:0.0913
# Discriminator_loss:1.3863
#
# EPOCH[47] - STEP[90]
# Generator_loss:12.0126
# L1_loss:0.1132
# Discriminator_loss:1.3863
#
# EPOCH[47] - STEP[100]
# Generator_loss:11.6574
# L1_loss:0.1096
# Discriminator_loss:1.3863
#
# EPOCH[47] - STEP[110]
# Generator_loss:10.2470
# L1_loss:0.0955
# Discriminator_loss:1.3863
#
# EPOCH[47] - STEP[120]
# Generator_loss:13.6294
# L1_loss:0.1294
# Discriminator_loss:1.3863
#
# EPOCH[47] - STEP[130]
# Generator_loss:15.0647
# L1_loss:0.1437
# Discriminator_loss:1.3863
#
# EPOCH[47] - STEP[140]
# Generator_loss:11.3467
# L1_loss:0.1065
# Discriminator_loss:1.3863
#
# EPOCH[47] - STEP[150]
# Generator_loss:13.9067
# L1_loss:0.1321
# Discriminator_loss:1.3863
#
# EPOCH[47] - STEP[160]
# Generator_loss:11.8071
# L1_loss:0.1111
# Discriminator_loss:1.3863
#
# EPOCH[47] - STEP[170]
# Generator_loss:16.5849
# L1_loss:0.1589
# Discriminator_loss:1.3863
#
# EPOCH[47] - STEP[180]
# Generator_loss:12.9481
# L1_loss:0.1225
# Discriminator_loss:1.3863
#
# EPOCH[47] - STEP[190]
# Generator_loss:16.7259
# L1_loss:0.1603
# Discriminator_loss:1.3863
#
# EPOCH[47] - STEP[200]
# Generator_loss:12.1996
# L1_loss:0.1151
# Discriminator_loss:1.3863
#
# EPOCH[47] - STEP[210]
# Generator_loss:14.1237
# L1_loss:0.1343
# Discriminator_loss:1.3863
#
# EPOCH[47] - STEP[220]
# Generator_loss:10.4418
# L1_loss:0.0975
# Discriminator_loss:1.3863
#
# EPOCH[47] - STEP[230]
# Generator_loss:10.8701
# L1_loss:0.1018
# Discriminator_loss:1.3863
#
# EPOCH[47] - STEP[240]
# Generator_loss:12.6382
# L1_loss:0.1195
# Discriminator_loss:1.3863
#
# EPOCH[47] - STEP[250]
# Generator_loss:12.3892
# L1_loss:0.1170
# Discriminator_loss:1.3863
#
# EPOCH[48] - STEP[10]
# Generator_loss:11.4614
# L1_loss:0.1077
# Discriminator_loss:1.3863
#
# EPOCH[48] - STEP[20]
# Generator_loss:13.4432
# L1_loss:0.1275
# Discriminator_loss:1.3863
#
# EPOCH[48] - STEP[30]
# Generator_loss:10.6067
# L1_loss:0.0991
# Discriminator_loss:1.3863
#
# EPOCH[48] - STEP[40]
# Generator_loss:12.0116
# L1_loss:0.1132
# Discriminator_loss:1.3863
#
# EPOCH[48] - STEP[50]
# Generator_loss:10.0959
# L1_loss:0.0940
# Discriminator_loss:1.3863
#
# EPOCH[48] - STEP[60]
# Generator_loss:15.8710
# L1_loss:0.1518
# Discriminator_loss:1.3863
#
# EPOCH[48] - STEP[70]
# Generator_loss:14.1154
# L1_loss:0.1342
# Discriminator_loss:1.3863
#
# EPOCH[48] - STEP[80]
# Generator_loss:15.6914
# L1_loss:0.1500
# Discriminator_loss:1.3863
#
# EPOCH[48] - STEP[90]
# Generator_loss:13.9817
# L1_loss:0.1329
# Discriminator_loss:1.3863
#
# EPOCH[48] - STEP[100]
# Generator_loss:13.0216
# L1_loss:0.1233
# Discriminator_loss:1.3863
#
# EPOCH[48] - STEP[110]
# Generator_loss:11.5640
# L1_loss:0.1087
# Discriminator_loss:1.3863
#
# EPOCH[48] - STEP[120]
# Generator_loss:11.1948
# L1_loss:0.1050
# Discriminator_loss:1.3863
#
# EPOCH[48] - STEP[130]
# Generator_loss:11.9759
# L1_loss:0.1128
# Discriminator_loss:1.3863
#
# EPOCH[48] - STEP[140]
# Generator_loss:17.3411
# L1_loss:0.1665
# Discriminator_loss:1.3863
#
# EPOCH[48] - STEP[150]
# Generator_loss:14.4885
# L1_loss:0.1380
# Discriminator_loss:1.3863
#
# EPOCH[48] - STEP[160]
# Generator_loss:8.7346
# L1_loss:0.0804
# Discriminator_loss:1.3863
#
# EPOCH[48] - STEP[170]
# Generator_loss:13.2442
# L1_loss:0.1255
# Discriminator_loss:1.3863
#
# EPOCH[48] - STEP[180]
# Generator_loss:11.1353
# L1_loss:0.1044
# Discriminator_loss:1.3863
#
# EPOCH[48] - STEP[190]
# Generator_loss:14.4900
# L1_loss:0.1380
# Discriminator_loss:1.3863
#
# EPOCH[48] - STEP[200]
# Generator_loss:16.2338
# L1_loss:0.1554
# Discriminator_loss:1.3863
#
# EPOCH[48] - STEP[210]
# Generator_loss:12.2214
# L1_loss:0.1153
# Discriminator_loss:1.3863
#
# EPOCH[48] - STEP[220]
# Generator_loss:15.4415
# L1_loss:0.1475
# Discriminator_loss:1.3863
#
# EPOCH[48] - STEP[230]
# Generator_loss:14.4197
# L1_loss:0.1373
# Discriminator_loss:1.3863
#
# EPOCH[48] - STEP[240]
# Generator_loss:11.4220
# L1_loss:0.1073
# Discriminator_loss:1.3863
#
# EPOCH[48] - STEP[250]
# Generator_loss:13.5675
# L1_loss:0.1287
# Discriminator_loss:1.3863
#
# EPOCH[49] - STEP[10]
# Generator_loss:11.1829
# L1_loss:0.1049
# Discriminator_loss:1.3863
#
# EPOCH[49] - STEP[20]
# Generator_loss:10.0589
# L1_loss:0.0937
# Discriminator_loss:1.3863
#
# EPOCH[49] - STEP[30]
# Generator_loss:13.1565
# L1_loss:0.1246
# Discriminator_loss:1.3863
#
# EPOCH[49] - STEP[40]
# Generator_loss:14.3772
# L1_loss:0.1368
# Discriminator_loss:1.3863
#
# EPOCH[49] - STEP[50]
# Generator_loss:12.2865
# L1_loss:0.1159
# Discriminator_loss:1.3863
#
# EPOCH[49] - STEP[60]
# Generator_loss:14.9954
# L1_loss:0.1430
# Discriminator_loss:1.3863
#
# EPOCH[49] - STEP[70]
# Generator_loss:10.3761
# L1_loss:0.0968
# Discriminator_loss:1.3863
#
# EPOCH[49] - STEP[80]
# Generator_loss:12.3055
# L1_loss:0.1161
# Discriminator_loss:1.3863
#
# EPOCH[49] - STEP[90]
# Generator_loss:11.8408
# L1_loss:0.1115
# Discriminator_loss:1.3863
#
# EPOCH[49] - STEP[100]
# Generator_loss:21.1473
# L1_loss:0.2045
# Discriminator_loss:1.3863
#
# EPOCH[49] - STEP[110]
# Generator_loss:17.9201
# L1_loss:0.1723
# Discriminator_loss:1.3863
#
# EPOCH[49] - STEP[120]
# Generator_loss:12.3023
# L1_loss:0.1161
# Discriminator_loss:1.3863
#
# EPOCH[49] - STEP[130]
# Generator_loss:12.4203
# L1_loss:0.1173
# Discriminator_loss:1.3863
#
# EPOCH[49] - STEP[140]
# Generator_loss:10.5691
# L1_loss:0.0988
# Discriminator_loss:1.3863
#
# EPOCH[49] - STEP[150]
# Generator_loss:11.0088
# L1_loss:0.1032
# Discriminator_loss:1.3863
#
# EPOCH[49] - STEP[160]
# Generator_loss:10.7472
# L1_loss:0.1005
# Discriminator_loss:1.3863
#
# EPOCH[49] - STEP[170]
# Generator_loss:9.3343
# L1_loss:0.0864
# Discriminator_loss:1.3863
#
# EPOCH[49] - STEP[180]
# Generator_loss:10.4157
# L1_loss:0.0972
# Discriminator_loss:1.3863
#
# EPOCH[49] - STEP[190]
# Generator_loss:10.5640
# L1_loss:0.0987
# Discriminator_loss:1.3863
#
# EPOCH[49] - STEP[200]
# Generator_loss:8.4674
# L1_loss:0.0777
# Discriminator_loss:1.3863
#
# EPOCH[49] - STEP[210]
# Generator_loss:11.1024
# L1_loss:0.1041
# Discriminator_loss:1.3863
#
# EPOCH[49] - STEP[220]
# Generator_loss:10.2828
# L1_loss:0.0959
# Discriminator_loss:1.3863
#
# EPOCH[49] - STEP[230]
# Generator_loss:12.3645
# L1_loss:0.1167
# Discriminator_loss:1.3863
#
# EPOCH[49] - STEP[240]
# Generator_loss:8.9755
# L1_loss:0.0828
# Discriminator_loss:1.3863
#
# EPOCH[49] - STEP[250]
# Generator_loss:12.7294
# L1_loss:0.1204
# Discriminator_loss:1.3863
#
# EPOCH[50] - STEP[10]
# Generator_loss:9.9136
# L1_loss:0.0922
# Discriminator_loss:1.3863
#
# EPOCH[50] - STEP[20]
# Generator_loss:17.7586
# L1_loss:0.1707
# Discriminator_loss:1.3863
#
# EPOCH[50] - STEP[30]
# Generator_loss:10.6309
# L1_loss:0.0994
# Discriminator_loss:1.3863
#
# EPOCH[50] - STEP[40]
# Generator_loss:10.6522
# L1_loss:0.0996
# Discriminator_loss:1.3863
#
# EPOCH[50] - STEP[50]
# Generator_loss:10.5340
# L1_loss:0.0984
# Discriminator_loss:1.3863
#
# EPOCH[50] - STEP[60]
# Generator_loss:11.1957
# L1_loss:0.1050
# Discriminator_loss:1.3863
#
# EPOCH[50] - STEP[70]
# Generator_loss:10.8394
# L1_loss:0.1015
# Discriminator_loss:1.3863
#
# EPOCH[50] - STEP[80]
# Generator_loss:9.1003
# L1_loss:0.0841
# Discriminator_loss:1.3863
#
# EPOCH[50] - STEP[90]
# Generator_loss:11.3523
# L1_loss:0.1066
# Discriminator_loss:1.3863
#
# EPOCH[50] - STEP[100]
# Generator_loss:12.5300
# L1_loss:0.1184
# Discriminator_loss:1.3863
#
# EPOCH[50] - STEP[110]
# Generator_loss:14.0470
# L1_loss:0.1335
# Discriminator_loss:1.3863
#
# EPOCH[50] - STEP[120]
# Generator_loss:10.4652
# L1_loss:0.0977
# Discriminator_loss:1.3863
#
# EPOCH[50] - STEP[130]
# Generator_loss:11.4626
# L1_loss:0.1077
# Discriminator_loss:1.3863
#
# EPOCH[50] - STEP[140]
# Generator_loss:11.3724
# L1_loss:0.1068
# Discriminator_loss:1.3863
#
# EPOCH[50] - STEP[150]
# Generator_loss:9.1632
# L1_loss:0.0847
# Discriminator_loss:1.3863
#
# EPOCH[50] - STEP[160]
# Generator_loss:12.8029
# L1_loss:0.1211
# Discriminator_loss:1.3863
#
# EPOCH[50] - STEP[170]
# Generator_loss:12.6151
# L1_loss:0.1192
# Discriminator_loss:1.3863
#
# EPOCH[50] - STEP[180]
# Generator_loss:12.9245
# L1_loss:0.1223
# Discriminator_loss:1.3863
#
# EPOCH[50] - STEP[190]
# Generator_loss:12.4720
# L1_loss:0.1178
# Discriminator_loss:1.3863
#
# EPOCH[50] - STEP[200]
# Generator_loss:11.4891
# L1_loss:0.1080
# Discriminator_loss:1.3863
#
# EPOCH[50] - STEP[210]
# Generator_loss:16.7581
# L1_loss:0.1606
# Discriminator_loss:1.3863
#
# EPOCH[50] - STEP[220]
# Generator_loss:10.2690
# L1_loss:0.0958
# Discriminator_loss:1.3863
#
# EPOCH[50] - STEP[230]
# Generator_loss:15.5239
# L1_loss:0.1483
# Discriminator_loss:1.3863
#
# EPOCH[50] - STEP[240]
# Generator_loss:11.1861
# L1_loss:0.1049
# Discriminator_loss:1.3863
#
# EPOCH[50] - STEP[250]
# Generator_loss:14.2603
# L1_loss:0.1357
# Discriminator_loss:1.3863

# %% [markdown]
# #  스케치, 생성된 사진, 실제 사진 순서로 나란히 시각화

# %%
test_ind = 1

f = data_path + os.listdir(data_path)[test_ind]
sketch, colored = load_img(f)

pred = generator(tf.expand_dims(sketch, 0))
pred = denormalize(pred)

plt.figure(figsize=(20,10))
plt.subplot(1,3,1); plt.imshow(denormalize(sketch))
plt.subplot(1,3,2); plt.imshow(pred[0])
plt.subplot(1,3,3); plt.imshow(denormalize(colored))

# %% [markdown]
# ### Step Loss 그래프 출력

# %%
plt.plot(loss_check)
plt.title("Loss By Step")
plt.xlabel('Step')
plt.ylabel('Loss')
plt.show()

# %% [markdown]
# # 회고
